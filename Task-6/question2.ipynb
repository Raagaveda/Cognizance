# %%
import pandas as pd
import csv
url = 'https://raw.githubusercontent.com/cognizance-amrita/AI-Tasks/main/Task-1/Q2-Dataset.csv'
dataframe = pd.read_csv(url)
dataframe.head()                   
dataframe.shape                  
dataframe.isnull()                 
dataframe.isnull().sum()          
dataframe.isnull().sum().sum()     
dataframe1_new = dataframe.fillna(value=0)   
dataframe1_new.isnull().sum().sum()   
dataframe1_new
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave     0      Reg
# 1    2          20       RL         80.0     9600   Pave     0      Reg
# 2    3          60       RL         68.0    11250   Pave     0      IR1
# 3    4          70       RL         60.0     9550   Pave     0      IR1
# 4    5          60       RL         84.0    14260   Pave     0      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL         69.0     9337   Pave     0      IR1
# 95  96          60       RL          0.0     9765   Pave     0      IR2
# 96  97          20       RL         78.0    10264   Pave     0      IR1
# 97  98          20       RL         73.0    10921   Pave     0      Reg
# 98  99          30       RL         85.0    10625   Pave     0      Reg
#
#    LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# ...
